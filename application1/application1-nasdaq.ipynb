# %% [markdown]
# ### 0.Crawl suspended stock list from NASDAQ

# %%
import re
from bs4 import BeautifulSoup
import urllib
import pandas as pd
import requests
import json

# %%
url = 'https://listingcenter.nasdaq.com/IssuersPendingSuspensionDelisting.aspx'
response = urllib.request.urlopen(url)
soup = BeautifulSoup(response, 'html.parser')

# %%
table = soup.find('table',{'class':'rgMasterTable'})

# %%
stock_list = []
for tr in table.tbody.findAll('tr'):
    row = []
    for td in tr.findAll('td'):
        text = td.getText()
        if text == '\xa0':
            text = 'None'
        row.append(text)
    stock_list.append(row)

# %%
df = pd.DataFrame(stock_list)
df.columns = ['Issuer Name','Symbol','Reason','Status','Effective Date','Form 25 Date']

# %%
df
# Out:
#                                           Issuer Name Symbol  \
# 0                             Altus Midstream Company  ALTMW
# 1                            Beneficial Bancorp, Inc.   BNCL
# 2                    Concrete Pumping Holdings, Inc.   BBCPW
# 3                     Eco-Stim Energy Solutions, Inc.   ESES
# 4                                  Elbit Imaging Ltd.  EMITF
# 5                   Helios and Matheson Analytics Inc   HMNY
# 6   Invesco Actively Managed Exchange-Traded Fund ...   LALT
# 7               Invesco Exchange-Traded Fund Trust II   DWLV
# 8               Invesco Exchange-Traded Fund Trust II   PAGG
# 9               Invesco Exchange-Traded Fund Trust II   PSAU
# 10                                  MiMedx Group, Inc   MDXG
# 11                              Nexeo Solutions, Inc.   NXEO
# 12                              Nexeo Solutions, Inc.  NXEOU
# 13                              Nexeo Solutions, Inc.  NXEOW
# 14                            One Horizon Group, Inc.   OHGI
# 15                       Organogenesis Holdings Inc.   ORGOW
# 16                 Pernix Therapeutics Holdings, Inc.    PTX
# 17                          ReShape Lifesciences Inc.   RSLS
# 18                             Real Goods Solar, Inc.   RGSE
# 19                            Reebonz Holding Limited  RBZAW
# 20              Simplicity Esports and Gaming Company   WINR
# 21              Simplicity Esports and Gaming Company  WINRW
# 22                         Super Micro Computer, Inc.   SMCI
# 23                                Waitr Holdings Inc.  WTRHW
# 24                       Yulong Eco-Materials Limited   YECO
#
#                        Reason     Status Effective Date Form 25 Date
# 0   Regulatory/Non Compliance  Suspended     12/20/2018    2/26/2019
# 1          Acquisition/Merger  Suspended       3/1/2019    2/28/2019
# 2   Regulatory/Non Compliance  Suspended      1/17/2019    2/26/2019
# 3   Regulatory/Non Compliance  Suspended       1/2/2019    2/26/2019
# 4   Regulatory/Non Compliance  Suspended      2/11/2019         None
# 5   Regulatory/Non Compliance  Suspended      2/13/2019         None
# 6                 Liquidation  Suspended      2/21/2019    2/28/2019
# 7                 Liquidation  Suspended      2/21/2019    2/28/2019
# 8                 Liquidation  Suspended      2/21/2019    2/28/2019
# 9                 Liquidation  Suspended      2/21/2019    2/28/2019
# 10  Regulatory/Non Compliance  Suspended      11/8/2018    2/26/2019
# 11         Acquisition/Merger  Suspended       3/1/2019     3/1/2019
# 12         Acquisition/Merger  Suspended       3/1/2019     3/1/2019
# 13         Acquisition/Merger  Suspended       3/1/2019     3/1/2019
# 14                       None    Trading           None         None
# 15  Regulatory/Non Compliance  Suspended       1/8/2019         None
# 16  Regulatory/Non Compliance  Suspended       3/5/2019         None
# 17  Regulatory/Non Compliance  Suspended     12/31/2018         None
# 18  Regulatory/Non Compliance  Suspended      2/15/2019         None
# 19  Regulatory/Non Compliance  Suspended      2/27/2019         None
# 20  Regulatory/Non Compliance  Suspended      1/25/2019         None
# 21  Regulatory/Non Compliance  Suspended      1/25/2019         None
# 22  Regulatory/Non Compliance  Suspended      8/23/2018         None
# 23  Regulatory/Non Compliance  Suspended     12/27/2018    2/26/2019
# 24  Regulatory/Non Compliance  Suspended     12/14/2018         None

# %% [markdown]
# #### Filter results with the status, as some may resume trading.

# %%
suspended_df = df[df['Status'] == "Suspended"]
suspended_df
# Out:
#                                           Issuer Name Symbol  \
# 0                             Altus Midstream Company  ALTMW
# 1                            Beneficial Bancorp, Inc.   BNCL
# 2                    Concrete Pumping Holdings, Inc.   BBCPW
# 3                     Eco-Stim Energy Solutions, Inc.   ESES
# 4                                  Elbit Imaging Ltd.  EMITF
# 5                   Helios and Matheson Analytics Inc   HMNY
# 6   Invesco Actively Managed Exchange-Traded Fund ...   LALT
# 7               Invesco Exchange-Traded Fund Trust II   DWLV
# 8               Invesco Exchange-Traded Fund Trust II   PAGG
# 9               Invesco Exchange-Traded Fund Trust II   PSAU
# 10                                  MiMedx Group, Inc   MDXG
# 11                              Nexeo Solutions, Inc.   NXEO
# 12                              Nexeo Solutions, Inc.  NXEOU
# 13                              Nexeo Solutions, Inc.  NXEOW
# 15                       Organogenesis Holdings Inc.   ORGOW
# 16                 Pernix Therapeutics Holdings, Inc.    PTX
# 17                          ReShape Lifesciences Inc.   RSLS
# 18                             Real Goods Solar, Inc.   RGSE
# 19                            Reebonz Holding Limited  RBZAW
# 20              Simplicity Esports and Gaming Company   WINR
# 21              Simplicity Esports and Gaming Company  WINRW
# 22                         Super Micro Computer, Inc.   SMCI
# 23                                Waitr Holdings Inc.  WTRHW
# 24                       Yulong Eco-Materials Limited   YECO
#
#                        Reason     Status Effective Date Form 25 Date
# 0   Regulatory/Non Compliance  Suspended     12/20/2018    2/26/2019
# 1          Acquisition/Merger  Suspended       3/1/2019    2/28/2019
# 2   Regulatory/Non Compliance  Suspended      1/17/2019    2/26/2019
# 3   Regulatory/Non Compliance  Suspended       1/2/2019    2/26/2019
# 4   Regulatory/Non Compliance  Suspended      2/11/2019         None
# 5   Regulatory/Non Compliance  Suspended      2/13/2019         None
# 6                 Liquidation  Suspended      2/21/2019    2/28/2019
# 7                 Liquidation  Suspended      2/21/2019    2/28/2019
# 8                 Liquidation  Suspended      2/21/2019    2/28/2019
# 9                 Liquidation  Suspended      2/21/2019    2/28/2019
# 10  Regulatory/Non Compliance  Suspended      11/8/2018    2/26/2019
# 11         Acquisition/Merger  Suspended       3/1/2019     3/1/2019
# 12         Acquisition/Merger  Suspended       3/1/2019     3/1/2019
# 13         Acquisition/Merger  Suspended       3/1/2019     3/1/2019
# 15  Regulatory/Non Compliance  Suspended       1/8/2019         None
# 16  Regulatory/Non Compliance  Suspended       3/5/2019         None
# 17  Regulatory/Non Compliance  Suspended     12/31/2018         None
# 18  Regulatory/Non Compliance  Suspended      2/15/2019         None
# 19  Regulatory/Non Compliance  Suspended      2/27/2019         None
# 20  Regulatory/Non Compliance  Suspended      1/25/2019         None
# 21  Regulatory/Non Compliance  Suspended      1/25/2019         None
# 22  Regulatory/Non Compliance  Suspended      8/23/2018         None
# 23  Regulatory/Non Compliance  Suspended     12/27/2018    2/26/2019
# 24  Regulatory/Non Compliance  Suspended     12/14/2018         None

# %% [markdown]
# ### 1. Build query structure
# #### query_list0 is for Google News; query_list1 is for Globenewswire

# %%
ticker = df.to_dict('index')

# %%
def build_query_list():
    query_list0 = []
    query_list1 = []
    for i in ticker:
        comp = re.sub(r'[,\.]',' ',ticker[i]['Issuer Name']).split()
        str_comp = '+'.join(comp)
        str_comp1 = ' '.join(comp)
        comp.append(ticker[i]['Symbol'])
        query = '+'.join(comp)
        query1 = ' '.join(comp)
        query_list0.append(query)
        query_list1.append(query1)
    return (query_list0, query_list1)

# %%
(query_list0, query_list1) = build_query_list()

# %% [markdown]
# #### After testing different combinations, we found that company_name+ticker is best for Globenewswire, while company_name+ticker+"stock"+"suspended" is bester for Google News.
#
# #### After testing different combinations of selecting the top-k retrieved results, we found that simply selecting the top 1 result from both news sources give a nice peroformance.

# %% [markdown]
# ### 2.1 Google News Crawler

# %%
# return top 1 results
def parseSingleNews(query):
    url = 'https://news.google.com/rss/search?q='+query+'+stock+suspend&hl=en-US&gl=US&ceid=US:en'
    response = urllib.request.urlopen(url)  
    soup = BeautifulSoup(response, 'html.parser')
    
    channel = soup.find('channel')
    news_list = []
    for item in soup.findAll('item')[0:1]:
        des = ''
        abst = ''
        description = item.find('description').get_text()
        match = re.search(r'(href=")(.*)(" target)',description)
        match1 = re.search(r'(<p>)(.*)(</p>)',description)
        if (match):
            des = match.group(2)
        if (match1):
            abst = match1.group(2)
        news_item = {
            'title':item.find('title').get_text(),
            'pubdate':item.find('pubdate').get_text(),
            'link':des,
            'abstract':abst
        }
        news_list.append(news_item)
    return news_list

# %%
def allQuery(query_list):
    dict = {}
    for q in query_list:
        q1 = q.replace('+',' ')
        news_list = parseSingleNews(q)
        dict[q1]=news_list
    return dict

# %%
google_news = allQuery(query_list0)

# %% [markdown]
# ### 2.2 Globenewswire Crawler

# %%
query_list2 = []
for q in query_list1:
    qry = {'keyword':q}
    query_list2.append(qry)

# %%
# return top 1 results
def parseSingleNews1(query):
    r = requests.get('https://globenewswire.com/Search', params=query)
    result = BeautifulSoup(r.text,'html.parser')
    contents = result.find_all("div", attrs = {"class" : "results-link"})
    news_list = []
    for content in contents[0:1]: 
        a = content.find("h1", attrs = {"class" : "post-title16px"}).find("a")
        title = a.text
        pubdate = content.find("span",attrs = {"class" : "dt-green"}).get_text()
        link = a['href']
        abstract = content.find_all("p")[1].text
        news_item = {
            'title':title,
            'pubdate':pubdate,
            'link':'https://globenewswire.com/'+link,
            'abstract':abstract
        }
        news_list.append(news_item)
    return news_list

# %%
def allQuery1(query_list):
    dict = {}
    for q in query_list:
        news_list = parseSingleNews1(q)
        dict[q['keyword']]=news_list
    return dict

# %%
globe_news = allQuery1(query_list2)

# %% [markdown]
# # Merge two sets

# %%
all_news = {}
for key in google_news:
    all_news[key] = google_news[key]
    all_news[key] += globe_news[key]

# %%
for k,v in all_news.items():
    print("Company name: {}".format(k))
    for i in v:
        print("\tRetrieved result:\t{}".format(i))
    print("------------------------------------\n")
# Out:
# Company name: Altus Midstream Company ALTMW
# 	Retrieved result:	{'title': 'Form PREM14A Kayne Anderson Acquisiti For: Aug 27 - StreetInsider.com', 'pubdate': 'Mon, 27 Aug 2018 07:00:00 GMT', 'link': 'https://www.streetinsider.com/SEC+Filings/Form+PREM14A+Kayne+Anderson+Acquisiti+For%3A+Aug+27/14551530.html', 'abstract': 'Filed by the Registrant ☒ Filed by a Party other than the Registrant ☐. Check the appropriate box: ☒, Preliminary Proxy Statement. ☐, Confidential, for Use of the ...'}
# 	Retrieved result:	{'title': 'Altus Midstream Company Acquires 15 Percent of Gulf Coast Express Pipeline', 'pubdate': 'December 19, 2018', 'link': 'https://globenewswire.com//news-release/2018/12/19/1669403/0/en/Altus-Midstream-Company-Acquires-15-Percent-of-Gulf-Coast-Express-Pipeline.html', 'abstract': 'HOUSTON, Dec.  19, 2018  (GLOBE NEWSWIRE) -- Altus Midstream Company (Nasdaq: ALTM, ALTMW) today announced its subsidiary, Altus Midstream LP, has exercised and closed its option with Kinder Morgan ...'}
# ------------------------------------
#
# Company name: Beneficial Bancorp Inc BNCL
# 	Retrieved result:	{'title': 'BENEFICIAL BANCORP,INC. (NASDAQ:BNCL) Files An 8-K Completion of Acquisition or Disposition of Assets - Market Exclusive', 'pubdate': 'Fri, 01 Mar 2019 20:55:00 GMT', 'link': 'https://marketexclusive.com/beneficial-bancorpinc-nasdaqbncl-files-an-8-k-completion-of-acquisition-or-disposition-of-assets/2019/03/', 'abstract': 'BENEFICIAL BANCORP,INC. (NASDAQ:BNCL) Files An 8-K Completion of Acquisition or Disposition of Assets Item 2.01Completion of Acquisition or ...'}
# 	Retrieved result:	{'title': 'WSFS Financial Corporation Receives All Required Approvals to Acquire Beneficial Bancorp, Inc.', 'pubdate': 'February 27, 2019', 'link': 'https://globenewswire.com//news-release/2019/02/27/1743855/0/en/WSFS-Financial-Corporation-Receives-All-Required-Approvals-to-Acquire-Beneficial-Bancorp-Inc.html', 'abstract': 'WILMINGTON, Del., Feb.  27, 2019  (GLOBE NEWSWIRE) -- WSFS Financial Corporation (Nasdaq: WSFS) (“WSFS”), the parent company of WSFS Bank, has received all required approvals to acquire Beneficial ...'}
# ------------------------------------
#
# Company name: Concrete Pumping Holdings Inc BBCPW
# 	Retrieved result:	{'title': 'Form 10-KT Concrete Pumping Holding For: Dec 05 - StreetInsider.com', 'pubdate': 'Tue, 29 Jan 2019 08:00:00 GMT', 'link': 'https://www.streetinsider.com/SEC+Filings/Form+10-KT+Concrete+Pumping+Holding+For%3A+Dec+05/15050179.html', 'abstract': 'UNITED STATES. SECURITIES AND EXCHANGE COMMISSION. Washington, D.C. 20549. FORM 10-K. (Mark One). ¨, ANNUAL REPORT PURSUANT TO ...'}
# 	Retrieved result:	{'title': 'Concrete Pumping Holdings Sets Fourth Quarter and Fiscal Year 2018 Earnings Conference Call for Tuesday, January 29, 2019', 'pubdate': 'January 16, 2019', 'link': 'https://globenewswire.com//news-release/2019/01/16/1696721/0/en/Concrete-Pumping-Holdings-Sets-Fourth-Quarter-and-Fiscal-Year-2018-Earnings-Conference-Call-for-Tuesday-January-29-2019.html', 'abstract': 'DENVER, Jan.  16, 2019  (GLOBE NEWSWIRE) -- Concrete Pumping Holdings, Inc. (Nasdaq: BBCP, BBCPW) (“CPH” or the “Company”), a leading provider of concrete pumping services and concrete waste ...'}
# ------------------------------------
#
# Company name: Eco-Stim Energy Solutions Inc ESES
# 	Retrieved result:	{'title': 'ECO-STIM ENERGY SOLUTIONS, INC. (NASDAQ:ESES) Files An 8-K Notice of Delisting or Failure to Satisfy a Continued Listing Rule or Standard; Transfer of Listing - Market Exclusive', 'pubdate': 'Wed, 26 Dec 2018 08:00:00 GMT', 'link': 'https://marketexclusive.com/eco-stim-energy-solutions-inc-nasdaqeses-files-an-8-k-notice-of-delisting-or-failure-to-satisfy-a-continued-listing-rule-or-standard-transfer-of-listing/2018/12/', 'abstract': 'ECO-STIM ENERGY SOLUTIONS, INC. (NASDAQ:ESES) Files An 8-K Notice of Delisting or Failure to Satisfy a Continued Listing Rule or Standard; Transfer of ...'}
# 	Retrieved result:	{'title': 'Eco-Stim Energy Solutions Releases Third Quarter Numbers', 'pubdate': 'November 14, 2018', 'link': 'https://globenewswire.com//news-release/2018/11/14/1651776/0/en/Eco-Stim-Energy-Solutions-Releases-Third-Quarter-Numbers.html', 'abstract': 'HOUSTON, TEXAS, Nov.  14, 2018  (GLOBE NEWSWIRE) -- Eco-Stim Energy Solutions, Inc. (NASDAQ: ESES) (“EcoStim” or the “Company”) today filed its quarterly report on Form 10-Q with the U.S. Securities ...'}
# ------------------------------------
#
# Company name: Elbit Imaging Ltd EMITF
# 	Retrieved result:	{'title': 'ELBIT IMAGING ANNOUNCES SUSPENSION OF TRADING OF ITS ORDINARY SHARES ON NASDAQ - GlobeNewswire', 'pubdate': 'Thu, 07 Feb 2019 08:00:00 GMT', 'link': 'https://globenewswire.com/news-release/2019/02/07/1713713/0/en/ELBIT-IMAGING-ANNOUNCES-SUSPENSION-OF-TRADING-OF-ITS-ORDINARY-SHARES-ON-NASDAQ.html', 'abstract': 'Tel Aviv, Israel, Feb. 07, 2019 (GLOBE NEWSWIRE) -- Elbit Imaging Ltd. (“EI” or the “Company”) (TASE, NASDAQ: EMITF) announced today that it received a ...'}
# 	Retrieved result:	{'title': 'ELBIT IMAGING ANNOUNCES AN UPDATE REGARDING THE DISPUTE IN CONNECTION WITH THE PLOT IN CHENNAI, INDIA', 'pubdate': 'March 04, 2019', 'link': 'https://globenewswire.com//news-release/2019/03/04/1745894/0/en/ELBIT-IMAGING-ANNOUNCES-AN-UPDATE-REGARDING-THE-DISPUTE-IN-CONNECTION-WITH-THE-PLOT-IN-CHENNAI-INDIA.html', 'abstract': 'Tel Aviv, Israel, March  04, 2019  (GLOBE NEWSWIRE) -- Elbit Imaging Ltd. (the “Company”) (TASE, NASDAQ: EMITF) announced today, further to its press release dated February 11, 2019, regarding the ...'}
# ------------------------------------
#
# Company name: Helios and Matheson Analytics Inc HMNY
# 	Retrieved result:	{'title': "NASDAQ Suspends Trading of Helios and Matheson Analytics Inc (OTCMKTS:HMNY)'s Stock - Tech Stock Observer", 'pubdate': 'Tue, 19 Feb 2019 08:00:00 GMT', 'link': 'https://techstockobserver.com/nasdaq-suspends-trading-of-helios-and-matheson-analytics-inc-otcmktshmnys-stock/', 'abstract': "NASDAQ will suspend the trading of Helios and Matheson Analytics Inc (OTCMKTS:HMNY)'s stock with effective from Wednesday. It will get delisted from the ..."}
# 	Retrieved result:	{'title': 'Consolidated Research: 2018 Summary Expectations for Comcast, Avnet, NIKE, Helios and Matheson Analytics, Quest Diagnostics, and Nevsun Resources — Fundamental Analysis, Key Performance Indications', 'pubdate': 'December 07, 2018', 'link': 'https://globenewswire.com//news-release/2018/12/07/1663754/0/en/Consolidated-Research-2018-Summary-Expectations-for-Comcast-Avnet-NIKE-Helios-and-Matheson-Analytics-Quest-Diagnostics-and-Nevsun-Resources-Fundamental-Analysis-Key-Performance-Ind.html', 'abstract': 'NEW YORK, Dec.  07, 2018  (GLOBE NEWSWIRE) -- In new independent research reports released early this morning, Market Source Research released its latest key findings for all current investors, ...'}
# ------------------------------------
#
# Company name: Invesco Actively Managed Exchange-Traded Fund Trus LALT
# 	Retrieved result:	{'title': 'Path Investments plc Heads of Agreement with ARC - DirectorsTalk Interviews', 'pubdate': 'Fri, 18 Jan 2019 08:00:00 GMT', 'link': 'https://www.directorstalkinterviews.com/path-investments-plc-heads-of-agreement-with-arc/412764669', 'abstract': 'Path Investments plc (LON: PATH) today announced that the Company has entered into a Heads of Agreement with ARC Marlborough Pty Limited regarding the.'}
# ------------------------------------
#
# Company name: Invesco Exchange-Traded Fund Trust II DWLV
# 	Retrieved result:	{'title': 'Path Investments plc Heads of Agreement with ARC - DirectorsTalk Interviews', 'pubdate': 'Fri, 18 Jan 2019 08:00:00 GMT', 'link': 'https://www.directorstalkinterviews.com/path-investments-plc-heads-of-agreement-with-arc/412764669', 'abstract': 'Path Investments plc (LON: PATH) today announced that the Company has entered into a Heads of Agreement with ARC Marlborough Pty Limited regarding the.'}
# ------------------------------------
#
# Company name: Invesco Exchange-Traded Fund Trust II PAGG
# 	Retrieved result:	{'title': 'Path Investments plc Heads of Agreement with ARC - DirectorsTalk Interviews', 'pubdate': 'Fri, 18 Jan 2019 08:00:00 GMT', 'link': 'https://www.directorstalkinterviews.com/path-investments-plc-heads-of-agreement-with-arc/412764669', 'abstract': 'Path Investments plc (LON: PATH) today announced that the Company has entered into a Heads of Agreement with ARC Marlborough Pty Limited regarding the.'}
# 	Retrieved result:	{'title': 'Invesco PowerShares to List Four Global Commodity-Producer ETFs on Nasdaq on Sept. 18', 'pubdate': 'September 17, 2008', 'link': 'https://globenewswire.com//news-release/2008/09/17/1173088/0/en/Invesco-PowerShares-to-List-Four-Global-Commodity-Producer-ETFs-on-Nasdaq-on-Sept-18.html', 'abstract': 'CHICAGO, IL--(Marketwire - September 17, 2008) -  Invesco PowerShares Capital Management LLC, a\nleading provider of exchange-traded funds (ETFs), announced four new equity\nETFs designed to provide ...'}
# ------------------------------------
#
# Company name: Invesco Exchange-Traded Fund Trust II PSAU
# 	Retrieved result:	{'title': 'Top 25 roundup: No. 17 Purdue edges PSU in OT - Investing.com', 'pubdate': 'Fri, 01 Feb 2019 08:00:00 GMT', 'link': 'https://www.investing.com/news/general-news/top-25-roundup-no-17-purdue-edges-psu-in-ot-1766134', 'abstract': 'Carsen Edwards scored 38 points to lead the No. 17 Boilermakers to a 99-90 overtime win at Penn State on Thursday, the third straight meeting at University ...'}
# 	Retrieved result:	{'title': 'Invesco PowerShares Adds Five ETFs to Schwab OneSource(TM) ', 'pubdate': 'February 10, 2015', 'link': 'https://globenewswire.com//news-release/2015/02/10/1173022/0/en/Invesco-PowerShares-Adds-Five-ETFs-to-Schwab-OneSource-TM.html', 'abstract': '\n CHICAGO, IL--(Marketwired - Feb 10, 2015) - Invesco PowerShares Capital Management, LLC ("PowerShares"), a leading global provider of exchange-traded funds (ETFs), announced today that it has ...'}
# ------------------------------------
#
# Company name: MiMedx Group Inc MDXG
# 	Retrieved result:	{'title': 'MiMedx Group, Inc. (MDXG) files 8-K | Thorold News - Thorold News', 'pubdate': 'Mon, 25 Feb 2019 21:34:48 GMT', 'link': 'https://whatsonthorold.com/2019/02/25/mimedx-group-inc-mdxg-files-8-k/', 'abstract': 'MiMedx Group, Inc. (MDXG) files 8-K in a filing on Feb 25.Item 3.01 Notice of Delisting or Failure to Satisfy a Continued Listing Rule or Standard; Transfer of.'}
# 	Retrieved result:	{'title': 'Bragar Eagel & Squire, P.C. Reminds Investors that it is Investigating the Board of Directors of MiMedx Group, Inc. (MDXG) on Behalf of Stockholders and Encourages Investors to Contact the Firm', 'pubdate': 'July 03, 2018', 'link': 'https://globenewswire.com//news-release/2018/07/03/1533143/0/en/Bragar-Eagel-Squire-P-C-Reminds-Investors-that-it-is-Investigating-the-Board-of-Directors-of-MiMedx-Group-Inc-MDXG-on-Behalf-of-Stockholders-and-Encourages-Investors-to-Contact-the.html', 'abstract': 'NEW YORK, July  03, 2018  (GLOBE NEWSWIRE) -- Bragar Eagel & Squire, P.C. reminds investors that the Firm is investigating potential claims against certain officers and directors of MiMedx Group, ...'}
# ------------------------------------
#
# Company name: Nexeo Solutions Inc NXEO
# 	Retrieved result:	{'title': 'Form S-4/A Univar Inc. - StreetInsider.com', 'pubdate': 'Wed, 09 Jan 2019 08:00:00 GMT', 'link': 'https://www.streetinsider.com/SEC+Filings/Form+S-4A+Univar+Inc./14993212.html', 'abstract': 'Delaware, 5169, 26-1251958. (State or Other Jurisdiction of. Incorporation or Organization). (Primary Standard Industrial. Classification Code Number).'}
# 	Retrieved result:	{'title': "Detailed Research: Economic Perspectives on Callon Petroleum, Summit Materials, Echo Global Logistics, BioCryst Pharmaceuticals, NEXEO SOLUTIONS, and NL Industries — What Drives Growth in Today's Competitive Landscape", 'pubdate': 'February 12, 2019', 'link': 'https://globenewswire.com//news-release/2019/02/12/1720671/0/en/Detailed-Research-Economic-Perspectives-on-Callon-Petroleum-Summit-Materials-Echo-Global-Logistics-BioCryst-Pharmaceuticals-NEXEO-SOLUTIONS-and-NL-Industries-What-Drives-Growth-in-.html', 'abstract': 'NEW YORK, Feb.  12, 2019  (GLOBE NEWSWIRE) -- In new independent research reports released early this morning, Fundamental Markets released its latest key findings for all current investors, traders, ...'}
# ------------------------------------
#
# Company name: Nexeo Solutions Inc NXEOU
# 	Retrieved result:	{'title': 'Path Investments plc Heads of Agreement with ARC - DirectorsTalk Interviews', 'pubdate': 'Fri, 18 Jan 2019 08:00:00 GMT', 'link': 'https://www.directorstalkinterviews.com/path-investments-plc-heads-of-agreement-with-arc/412764669', 'abstract': 'Path Investments plc (LON: PATH) today announced that the Company has entered into a Heads of Agreement with ARC Marlborough Pty Limited regarding the.'}
# ------------------------------------
#
# Company name: Nexeo Solutions Inc NXEOW
# 	Retrieved result:	{'title': 'Path Investments plc Heads of Agreement with ARC - DirectorsTalk Interviews', 'pubdate': 'Fri, 18 Jan 2019 08:00:00 GMT', 'link': 'https://www.directorstalkinterviews.com/path-investments-plc-heads-of-agreement-with-arc/412764669', 'abstract': 'Path Investments plc (LON: PATH) today announced that the Company has entered into a Heads of Agreement with ARC Marlborough Pty Limited regarding the.'}
# ------------------------------------
#
# Company name: One Horizon Group Inc OHGI
# 	Retrieved result:	{'title': 'U.S. stocks higher at close of trade; Dow Jones Industrial Average up 1.77% - Investing.com', 'pubdate': 'Wed, 30 Jan 2019 08:00:00 GMT', 'link': 'https://www.investing.com/news/stock-market-news/us-stocks-higher-at-close-of-trade-dow-jones-industrial-average-up-177-1764080', 'abstract': 'Investing.com – U.S. stocks were higher after the close on Wednesday, as gains in the Technology, Industrials and Healthcare sectors led shares higher.'}
# 	Retrieved result:	{'title': 'One Horizon Group Announces Voluntary Delisting from NASDAQ', 'pubdate': 'February 26, 2019', 'link': 'https://globenewswire.com//news-release/2019/02/26/1742978/0/en/One-Horizon-Group-Announces-Voluntary-Delisting-from-NASDAQ.html', 'abstract': 'MIAMI, Feb.  26, 2019  (GLOBE NEWSWIRE) -- One Horizon Group, Inc. (NASDAQ: OHGI) (the “Company”) today announced that it has notified The Nasdaq Stock Market LLC (“NASDAQ”) of its intent to withdraw ...'}
# ------------------------------------
#
# Company name: Organogenesis Holdings Inc ORGOW
# 	Retrieved result:	{'title': 'Form 424B3 Organogenesis Holdings - StreetInsider.com', 'pubdate': 'Mon, 04 Feb 2019 08:00:00 GMT', 'link': 'https://www.streetinsider.com/SEC+Filings/Form+424B3+Organogenesis+Holdings/15073088.html', 'abstract': 'The Selling Stockholders named in this prospectus or their permitted transferees may offer and sell from time to time up to 46,853,325 shares of our Class A ...'}
# ------------------------------------
#
# Company name: Pernix Therapeutics Holdings Inc PTX
# 	Retrieved result:	{'title': 'Pernix Therapeutics Reports Fourth Quarter and Full Year 2017 Financial Results - GlobeNewswire', 'pubdate': 'Thu, 08 Mar 2018 08:00:00 GMT', 'link': 'https://globenewswire.com/news-release/2018/03/08/1418745/0/en/Pernix-Therapeutics-Reports-Fourth-Quarter-and-Full-Year-2017-Financial-Results.html', 'abstract': 'MORRISTOWN, N.J., March 08, 2018 (GLOBE NEWSWIRE) -- Pernix Therapeutics Holdings, Inc. (NASDAQ:PTX), a specialty pharmaceutical company, ...'}
# 	Retrieved result:	{'title': 'Pernix Therapeutics Holdings, Inc. Enters into Asset Purchase Agreement with Certain Funds Managed by Highbridge Capital Management', 'pubdate': 'February 19, 2019', 'link': 'https://globenewswire.com//news-release/2019/02/19/1734397/0/en/Pernix-Therapeutics-Holdings-Inc-Enters-into-Asset-Purchase-Agreement-with-Certain-Funds-Managed-by-Highbridge-Capital-Management.html', 'abstract': 'Transaction that includes the sale of substantially all of Pernix’s assets to be valued at $75.6 million  \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Pernix voluntarily files for Chapter 11 protection   Pernix intends to continue to ...'}
# ------------------------------------
#
# Company name: ReShape Lifesciences Inc RSLS
# 	Retrieved result:	{'title': 'ReShape shares halted pending news; shares up 7% - Seeking Alpha', 'pubdate': 'Mon, 26 Nov 2018 08:00:00 GMT', 'link': 'https://seekingalpha.com/news/3412151-reshape-shares-halted-pending-news-shares-7-percent', 'abstract': 'Nasdaq has suspended trading in ReShape Lifesciences ([[RSLS]] +7.2%) pending the release of news. Update: In a direct offering, the company intends to sel.'}
# 	Retrieved result:	{'title': 'Consolidated Research: 2018 Summary Expectations for Envision Healthcare, Taylor Morrison Home, Vertex Pharmaceuticals, ReShape Lifesciences Inc., American Axle & Manufacturing, and Lattice Semiconductor — Fundamental Analysis, Key Performance Indications', 'pubdate': 'March 09, 2018', 'link': 'https://globenewswire.com//news-release/2018/03/09/1419876/0/en/Consolidated-Research-2018-Summary-Expectations-for-Envision-Healthcare-Taylor-Morrison-Home-Vertex-Pharmaceuticals-ReShape-Lifesciences-Inc-American-Axle-Manufacturing-and-Lattice.html', 'abstract': 'NEW YORK, March  09, 2018  (GLOBE NEWSWIRE) -- In new independent research reports released early this morning, Fundamental Markets released its latest key findings for all current investors, traders, ...'}
# ------------------------------------
#
# Company name: Real Goods Solar Inc RGSE
# 	Retrieved result:	{'title': 'REAL GOODS SOLAR, INC. (NASDAQ:RGSE) Files An 8-K Notice of Delisting or Failure to Satisfy a Continued Listing Rule or Standard; Transfer of Listing - Market Exclusive', 'pubdate': 'Fri, 08 Feb 2019 08:00:00 GMT', 'link': 'https://marketexclusive.com/real-goods-solar-inc-nasdaqrgse-files-an-8-k-notice-of-delisting-or-failure-to-satisfy-a-continued-listing-rule-or-standard-transfer-of-listing-2/2019/02/', 'abstract': 'REAL GOODS SOLAR, INC. (NASDAQ:RGSE) Files An 8-K Notice of Delisting or Failure to Satisfy a Continued Listing Rule or Standard; Transfer of Listing'}
# 	Retrieved result:	{'title': "RGS Energy’s POWERHOUSE™ 3.0 Solar Shingles Wins Best Energy Efficient Product at The NAHB International Builders' Show® ", 'pubdate': 'February 25, 2019', 'link': 'https://globenewswire.com//news-release/2019/02/25/1741571/0/en/RGS-Energy-s-POWERHOUSE-3-0-Solar-Shingles-Wins-Best-Energy-Efficient-Product-at-The-NAHB-International-Builders-Show.html', 'abstract': 'DENVER, Feb.  25, 2019  (GLOBE NEWSWIRE) -- RGS Energy (OTCQX: RGSE), the exclusive worldwide manufacturer of the visually stunning POWERHOUSE™ Solar Shingle System, won “Best Energy Efficient ...'}
# ------------------------------------
#
# Company name: Reebonz Holding Limited RBZAW
# 	Retrieved result:	{'title': 'Nasdaq Grants Extension to Reebonz Holding Limited for Continued Listing of Shares - Nasdaq', 'pubdate': 'Tue, 26 Feb 2019 12:00:00 GMT', 'link': 'https://www.nasdaq.com/press-release/nasdaq-grants-extension-to-reebonz-holding-limited-for--continued-listing-of-shares-20190226-00566', 'abstract': 'SINGAPORE, Feb. 26, 2019-- Reebonz Holding Limited, a leading online luxury marketplace and platform in Southeast Asia, today announced that the.'}
# 	Retrieved result:	{'title': 'Nasdaq Grants Extension to Reebonz Holding Limited for  Continued Listing of Shares', 'pubdate': 'February 26, 2019', 'link': 'https://globenewswire.com//news-release/2019/02/26/1742417/0/en/Nasdaq-Grants-Extension-to-Reebonz-Holding-Limited-for-Continued-Listing-of-Shares.html', 'abstract': 'SINGAPORE, Feb.  26, 2019  (GLOBE NEWSWIRE) -- Reebonz Holding Limited (the “Company” or “Reebonz”) (Nasdaq: RBZ), a leading online luxury marketplace and platform in Southeast Asia, today announced ...'}
# ------------------------------------
#
# Company name: Simplicity Esports and Gaming Company WINR
# 	Retrieved result:	{'title': '2016 Console Showdown: Xbox One Vs PlayStation 4 - Lifehacker Australia', 'pubdate': 'Mon, 19 Dec 2016 08:00:00 GMT', 'link': 'https://www.lifehacker.com.au/2016/12/2016-console-showdown-xbox-one-vs-playstation-4/', 'abstract': '2016 was a truly massive year for the PlayStation 4 and Xbox One. Both consoles received significant hardware upgrades, bringing the total number on the ...'}
# 	Retrieved result:	{'title': 'Simplicity Esports and Gaming Company Announces Commencement of Trading on OTCQB', 'pubdate': 'January 25, 2019', 'link': 'https://globenewswire.com//news-release/2019/01/25/1705580/0/en/Simplicity-Esports-and-Gaming-Company-Announces-Commencement-of-Trading-on-OTCQB.html', 'abstract': 'NEW YORK, Jan.  25, 2019  (GLOBE NEWSWIRE) -- Simplicity Esports and Gaming Company (OTCQB: WINR) (the “Company”), announced it will begin trading on January 25, 2019 on the OTCQB. Management decided ...'}
# ------------------------------------
#
# Company name: Simplicity Esports and Gaming Company WINRW
# 	Retrieved result:	{'title': 'UTA Promotes 9 Coordinators to Agent and 1 Assistant to Executive - TheWrap', 'pubdate': 'Thu, 25 Oct 2018 07:00:00 GMT', 'link': 'https://www.thewrap.com/uta-promotes-9-coordinators-to-agent-and-1-agent-to-executive/', 'abstract': 'United Talent Agency announced on Thursday that it has promoted nine coordinators to agent status, and one agent who was promoted to executive.'}
# 	Retrieved result:	{'title': 'Simplicity Esports and Gaming Company Announces New Commencement Date for Trading Under its New Ticker Symbols', 'pubdate': 'January 09, 2019', 'link': 'https://globenewswire.com//news-release/2019/01/09/1685836/0/en/Simplicity-Esports-and-Gaming-Company-Announces-New-Commencement-Date-for-Trading-Under-its-New-Ticker-Symbols.html', 'abstract': 'NEW YORK, Jan.  09, 2019  (GLOBE NEWSWIRE) -- Simplicity Esports and Gaming Company, formerly known as SMAAASH Entertainment Inc. (NASDAQ: SMSH) (the “Company”), announced today that the date for the ...'}
# ------------------------------------
#
# Company name: Super Micro Computer Inc SMCI
# 	Retrieved result:	{'title': 'Super Micro Computer Inc (NASDAQ:SMCI) Stock Price Down as Sentiment Drops - MoneyMakingArticles', 'pubdate': 'Sun, 03 Mar 2019 16:39:08 GMT', 'link': 'https://www.mmahotstuff.com/2019/03/03/super-micro-computer-inc-nasdaqsmci-stock-price-down-as-sentiment-drops.html', 'abstract': 'Super Micro Computer Inc (NASDAQ:SMCI) institutional sentiment decreased to 0.16 in Q3 2018. Its down -1.24, from 1.4 in 2018Q2. The ratio dropped, as 17 ...'}
# 	Retrieved result:	{'title': 'Bragar Eagel & Squire, P.C. Reminds Investors that it is Investigating Seaboard, Menlo, Super Micro, and NiSource on Behalf of Stockholders and Encourages Investors to Contact the Firm', 'pubdate': 'November 05, 2018', 'link': 'https://globenewswire.com//news-release/2018/11/05/1645623/0/en/Bragar-Eagel-Squire-P-C-Reminds-Investors-that-it-is-Investigating-Seaboard-Menlo-Super-Micro-and-NiSource-on-Behalf-of-Stockholders-and-Encourages-Investors-to-Contact-the-Firm.html', 'abstract': 'NEW YORK, Nov.  05, 2018  (GLOBE NEWSWIRE) -- Bragar Eagel & Squire, P.C. reminds investors that it is investigating potential claims on behalf of stockholders of Seaboard Corporation, Menlo ...'}
# ------------------------------------
#
# Company name: Waitr Holdings Inc WTRHW
# 	Retrieved result:	{'title': 'Path Investments plc Heads of Agreement with ARC - DirectorsTalk Interviews', 'pubdate': 'Fri, 18 Jan 2019 08:00:00 GMT', 'link': 'https://www.directorstalkinterviews.com/path-investments-plc-heads-of-agreement-with-arc/412764669', 'abstract': 'Path Investments plc (LON: PATH) today announced that the Company has entered into a Heads of Agreement with ARC Marlborough Pty Limited regarding the.'}
# ------------------------------------
#
# Company name: Yulong Eco-Materials Limited YECO
# 	Retrieved result:	{'title': 'Yulong Eco-Materials Limited Announces NASDAQ Delisting - Nasdaq', 'pubdate': 'Thu, 13 Dec 2018 08:00:00 GMT', 'link': 'https://www.nasdaq.com/press-release/yulong-ecomaterials-limited-announces-nasdaq-delisting-20181213-01078', 'abstract': 'New York, Dec. 13, 2018-- Yulong Eco-Materials Limited, announced today that it has received notice from The Nasdaq Stock Market that Nasdaq will.'}
# 	Retrieved result:	{'title': 'Yulong Eco-Materials Limited Announces NASDAQ Delisting', 'pubdate': 'December 13, 2018', 'link': 'https://globenewswire.com//news-release/2018/12/13/1667046/0/en/Yulong-Eco-Materials-Limited-Announces-NASDAQ-Delisting.html', 'abstract': 'New York, Dec.  13, 2018  (GLOBE NEWSWIRE) -- Yulong Eco-Materials Limited (NASDAQ: YECO) (the “Company”), announced today that it has received notice from The Nasdaq Stock Market (“Nasdaq”) that ...'}
# ------------------------------------

# %% [markdown]
# ## Load to json file

# %%
formatted_results = {}
formatted_results["news"] = []

# %%
for k,v in all_news.items():
    result = {}
    result["company_name"] = k
    result["company_news"] = v
    formatted_results["news"].append(result)

# %%
import json
with open('result.json', 'w') as fp:
    json.dump(formatted_results, fp)
